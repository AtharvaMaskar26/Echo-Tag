# %% [markdown]
# ### Installing Libraries
#
# Librosa helps us to work well with audio files

# %%
# !pip install librosa
# Out:
# ...
#   Obtaining dependency information for librosa from https://files.pythonhosted.org/packages/e2/a2/4f639c1168d7aada749a896afb4892a831e2041bebdcf636aebfe9e86556/librosa-0.10.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for audioread>=2.1.9 from https://files.pythonhosted.org/packages/57/8d/30aa32745af16af0a9a650115fbe81bde7c610ed5c21b381fca0196f3a7f/audioread-3.0.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for soundfile>=0.12.1 from https://files.pythonhosted.org/packages/50/ff/26a4ee48d0b66625a4e4028a055b9f25bc9d7c7b2d17d21a45137621a50d/soundfile-0.12.1-py2.py3-none-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for soxr>=0.3.2 from https://files.pythonhosted.org/packages/0d/95/8398287a3a00d006ebbe5fcada88bb2536acde2beecce892ff091e1c1a3b/soxr-0.3.7-cp311-cp311-win_amd64.whl.metadata
# ...

# %% [markdown]
# ### Importing Libraries

# %%
import matplotlib.pyplot as plt # Helps us to display an audio file in the form of signals
# %matplotlib inline

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
filename = 'dog_bark_test.wav'

# %%
plt.figure(figsize=(14, 5))

# This gives us 2 things, data and sample_rate
data, sample_rate = librosa.load(filename)

# This displays the waveform 
librosa.display.waveshow(data, sr=sample_rate, color = "red")

# Plays the sound
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# What is a sample rate?
#
# -  the number of samples per second that are taken of a waveform to create a discete digital signal
#
# Mono -> Sound will be equally propogated form both ends of a headphone
# Stereo -> Some sound might be more in the right ear than the left ear
#
# So what librosa does is, it tries to convert all the sounds of any sample rate to a sample rate of 22050

# %%
sample_rate
# Out:
# 22050

# %%
from scipy.io import wavfile as wav

wav_sample_rate, wave_audio = wav.read(filename)

# %%
wav_sample_rate
# Out:
# 48000

# %% [markdown]
# These values are achieved at differnt points and it together forms a wave, librosa normalizes these values in a scale of -1 to 1

# %%
wave_audio
# Out:
# array([-535, -494, -371, ...,  340,  844, 1216], dtype=int16)

# %%
import pandas as pd 

metadata = pd.read_csv('UrbanSound8K/metadata/UrbanSound8K.csv')

metadata.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 3
#       1 import pandas as pd
# ----> 3 metadata = pd.read_csv('UrbanSound8K/metadata/UrbanSound8K.csv')
#       5 metadata.head()
#
# ...
